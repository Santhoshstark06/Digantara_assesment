# %% [markdown]
# <a href="https://colab.research.google.com/github/Santhoshstark06/Digantara_assesment/blob/main/Conjuntion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the data
file_path = '/content/sort-minRange.csv'
data = pd.read_csv(file_path)

# Display the head of the dataframe
data.head()
# Out:
#    NORAD_CAT_ID_1                 OBJECT_NAME_1  DSE_1  NORAD_CAT_ID_2  \
# 0           53399             STARLINK-4528 [+]  4.188           23608
# 1           39491  COSMOS 2494 (SKRL-756 2) [+]  5.649           49152
# 2           57151             STARLINK-5776 [+]  7.167           34958
# 3           53885                  OBJECT B [+]  4.196           54368
# 4           47523               FLOCK 4S-10 [+]  1.780           56494
#
#          OBJECT_NAME_2  DSE_2                      TCA  TCA_RANGE  \
# 0  ARIANE 40+3 R/B [-]  3.598  2023-11-11 16:56:23.932      0.019
# 1    STARLINK-3081 [+]  5.686  2023-11-13 18:41:10.762      0.022
# 2  COSMOS 2251 DEB [-]  8.051  2023-11-15 06:37:35.811      0.022
# 3   ASTROCAST-0303 [+]  4.469  2023-11-12 07:24:40.503      0.026
# 4    STARLINK-5530 [+]  1.320  2023-11-08 21:41:15.038      0.036
#
#    TCA_RELATIVE_SPEED  MAX_PROB  DILUTION
# 0              10.712  0.218200     0.006
# 1              13.704  0.040210     0.010
# 2               6.630  0.008498     0.006
# 3              10.045  0.005081     0.008
# 4              10.471  0.001283     0.011

# %%
import matplotlib.pyplot as plt

# Plot the distribution of TCA_RANGE values
plt.figure(figsize=(10, 6))
plt.hist(data['TCA_RANGE'], bins=50, color='skyblue', edgecolor='black')
plt.title('Distribution of TCA_RANGE Values')
plt.xlabel('TCA_RANGE')
plt.ylabel('Frequency')
plt.show()

# %%
# Convert TCA to datetime format
\
data['TCA'] = pd.to_datetime(data['TCA'])

\
# Get the most recent day in the data
\
recent_day = data['TCA'].dt.date.max()

\
# Filter the data for the most recent day
\
data_day = data[data['TCA'].dt.date == recent_day]

\
# Display the head of the filtered dataframe
\
data_day.head()
# Out:
#      NORAD_CAT_ID_1                 OBJECT_NAME_1  DSE_1  NORAD_CAT_ID_2  \
# 2             57151             STARLINK-5776 [+]  7.167           34958
# 24            33408  SHIJIAN-6 03A (SJ-6 03A) [+]  7.595           56823
# 39            52491             STARLINK-3908 [+]  7.119           57027
# 45            56992                  URESAT-1 [+]  6.960           57483
# 106           37930  CHUANGXIN 1-03 (CX-1-03) [+]  7.192           42391
#
#            OBJECT_NAME_2  DSE_2                     TCA  TCA_RANGE  \
# 2    COSMOS 2251 DEB [-]  8.051 2023-11-15 06:37:35.811      0.022
# 24    STARLINK-30119 [+]  7.565 2023-11-15 03:37:08.193      0.094
# 39          OBJECT Z [+]  7.418 2023-11-15 05:54:36.443      0.117
# 45    ORB-12 STRIDER [+]  7.324 2023-11-15 01:15:01.030      0.125
# 106      NOAA 16 DEB [-]  7.835 2023-11-15 07:09:41.359      0.194
#
#      TCA_RELATIVE_SPEED  MAX_PROB  DILUTION
# 2                 6.630  0.008498     0.006
# 24                9.988  0.000392     0.028
# 39               14.690  0.001198     0.067
# 45               11.561  0.000195     0.042
# 106              14.739  0.000043     0.125

# %%
# Convert TCA to datetime format
\
data['TCA'] = pd.to_datetime(data['TCA'])

\
# Get the most recent day in the data
\
recent_day = data['TCA'].dt.date.max()

\
# Filter the data for the most recent day
\
data_day = data[data['TCA'].dt.date == recent_day]

\
# Display the head of the filtered dataframe
\
data_day.head()
# Out:
#      NORAD_CAT_ID_1                 OBJECT_NAME_1  DSE_1  NORAD_CAT_ID_2  \
# 2             57151             STARLINK-5776 [+]  7.167           34958
# 24            33408  SHIJIAN-6 03A (SJ-6 03A) [+]  7.595           56823
# 39            52491             STARLINK-3908 [+]  7.119           57027
# 45            56992                  URESAT-1 [+]  6.960           57483
# 106           37930  CHUANGXIN 1-03 (CX-1-03) [+]  7.192           42391
#
#            OBJECT_NAME_2  DSE_2                     TCA  TCA_RANGE  \
# 2    COSMOS 2251 DEB [-]  8.051 2023-11-15 06:37:35.811      0.022
# 24    STARLINK-30119 [+]  7.565 2023-11-15 03:37:08.193      0.094
# 39          OBJECT Z [+]  7.418 2023-11-15 05:54:36.443      0.117
# 45    ORB-12 STRIDER [+]  7.324 2023-11-15 01:15:01.030      0.125
# 106      NOAA 16 DEB [-]  7.835 2023-11-15 07:09:41.359      0.194
#
#      TCA_RELATIVE_SPEED  MAX_PROB  DILUTION
# 2                 6.630  0.008498     0.006
# 24                9.988  0.000392     0.028
# 39               14.690  0.001198     0.067
# 45               11.561  0.000195     0.042
# 106              14.739  0.000043     0.125

# %%
# Total number of conjunction events for the day
\
total_conjunctions = len(data_day)

\
# Number of conjunctions among active satellites
\
active_conjunctions = len(data_day[(data_day['OBJECT_NAME_1'].str.contains('\+')) & (data_day['OBJECT_NAME_2'].str.contains('\+'))])

\
total_conjunctions, active_conjunctions
# Out:
# (1382, 510)

# %%
# Total number of conjunction events for the day
\
total_conjunctions = len(data_day)

\
# Number of conjunctions among active satellites
\
active_conjunctions = len(data_day[(data_day['OBJECT_NAME_1'].str.contains('\+')) & (data_day['OBJECT_NAME_2'].str.contains('\+'))])

\
total_conjunctions, active_conjunctions
# Out:
# (1382, 510)

# %%
# Plot the distribution of TCA_RANGE values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['TCA_RANGE'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of TCA_RANGE Values for the Day')
\
plt.xlabel('TCA_RANGE')
\
plt.ylabel('Frequency')
\
plt.show()

\
# Plot the distribution of TCA_RELATIVE_SPEED values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['TCA_RELATIVE_SPEED'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of TCA_RELATIVE_SPEED Values for the Day')
\
plt.xlabel('TCA_RELATIVE_SPEED')
\
plt.ylabel('Frequency')
\
plt.show()

# %%
\
# Plot the distribution of MAX_PROB values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['MAX_PROB'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of MAX_PROB Values for the Day')
\
plt.xlabel('MAX_PROB')
\
plt.ylabel('Frequency')
\
plt.show()

# %%
# Extract the hour from the TCA column
\
data_day['TCA_HOUR'] = data_day['TCA'].dt.hour

\
# Count the number of events per hour
\
events_per_hour = data_day['TCA_HOUR'].value_counts().sort_index()

\
# Plot the number of events per hour
\
plt.figure(figsize=(10, 6))
\
plt.plot(events_per_hour.index, events_per_hour.values, marker='o')
\
plt.title('Number of Conjunction Events Per Hour for the Day')
\
plt.xlabel('Hour of the Day')
\
plt.ylabel('Number of Events')
\
plt.grid(True)
\
plt.show()
# Out:
# <ipython-input-10-b6741e031d85>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_day['TCA_HOUR'] = data_day['TCA'].dt.hour

# %%
# Extract the hour from the TCA column
\
data_day['TCA_HOUR'] = data_day['TCA'].dt.hour

\
# Count the number of events per hour
\
events_per_hour = data_day['TCA_HOUR'].value_counts().sort_index()

\
# Plot the number of events per hour
\
plt.figure(figsize=(10, 6))
\
plt.plot(events_per_hour.index, events_per_hour.values, marker='o')
\
plt.title('Number of Conjunction Events Per Hour for the Day')
\
plt.xlabel('Hour of the Day')
\
plt.ylabel('Number of Events')
\
plt.grid(True)
\
plt.show()
# Out:
# <ipython-input-11-b6741e031d85>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_day['TCA_HOUR'] = data_day['TCA'].dt.hour

# %%
# Calculate the average MAX_PROB for the day
\
average_max_prob = data_day['MAX_PROB'].mean()

\
# Plot the distribution of MAX_PROB values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['MAX_PROB'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of MAX_PROB Values for the Day')
\
plt.xlabel('MAX_PROB')
\
plt.ylabel('Frequency')
\
plt.show()

\
average_max_prob
# Out:
# 1.5148566222865415e-05

# %%
# Calculate the average MIN_RANGE for the day
\
average_min_range = data_day['MIN_RANGE'].mean()

\
# Plot the distribution of MIN_RANGE values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['MIN_RANGE'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of MIN_RANGE Values for the Day')
\
plt.xlabel('MIN_RANGE')
\
plt.ylabel('Frequency')
\
plt.show()

\
average_min_range
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MIN_RANGE'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-a62e82de4469> in <cell line: 3>()
#       1 # Calculate the average MIN_RANGE for the day
#       2 \
# ----> 3 average_min_range = data_day['MIN_RANGE'].mean()
#       4
#       5 \
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'MIN_RANGE'

# %%
# Calculate the average TCA_RANGE for the day
\
average_tca_range = data_day['TCA_RANGE'].mean()

\
# Plot the distribution of TCA_RANGE values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['TCA_RANGE'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of TCA_RANGE Values for the Day')
\
plt.xlabel('TCA_RANGE')
\
plt.ylabel('Frequency')
\
plt.show()

\
average_tca_range
# Out:
# 2.1798342981186685

# %%
# Calculate the average TCA_RELATIVE_SPEED for the day
\
average_tca_relative_speed = data_day['TCA_RELATIVE_SPEED'].mean()

\
# Plot the distribution of TCA_RELATIVE_SPEED values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['TCA_RELATIVE_SPEED'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of TCA_RELATIVE_SPEED Values for the Day')
\
plt.xlabel('TCA_RELATIVE_SPEED')
\
plt.ylabel('Frequency')
\
plt.show()

\
average_tca_relative_speed
# Out:
# 11.456057887120116

# %%
# Calculate the average DILUTION for the day
\
average_dilution = data_day['DILUTION'].mean()

\
# Plot the distribution of DILUTION values for the day
\
plt.figure(figsize=(10, 6))
\
plt.hist(data_day['DILUTION'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of DILUTION Values for the Day')
\
plt.xlabel('DILUTION')
\
plt.ylabel('Frequency')
\
plt.show()

\
average_dilution
# Out:
# 0.9190354558610709

# %% [markdown]
# # New section

# %% [markdown]
# question 2

# %% [markdown]
# Represent the conjunctions data of a single satellite or a satellite constellation.
# The analytics should be intuitive, represented in an easily understandable format and
# should enable decision making from a satellite operator’s point of view.To represent the conjunction data of a single satellite or a satellite constellation, we can perform the following steps:
#
# 1. **Filter the data for the specific satellite or constellation**: We'll need to filter the data to only include events that involve the satellite or satellites of interest. This can be done by filtering on the 'NORAD_CAT_ID_1' and 'NORAD_CAT_ID_2' columns.
#
# 2. **Time series analysis**: We can plot the number of conjunction events over time to understand the frequency of these events. This can help the satellite operator understand when they might need to be more alert for potential conjunction events.
#
# 3. **Risk analysis**: We can analyze the 'MAX_PROB' column to understand the risk of each conjunction event. This can be visualized with a histogram or a box plot to understand the distribution of risk.
#
# 4. **Speed and Range analysis**: We can analyze the 'TCA_RELATIVE_SPEED' and 'TCA_RANGE' columns to understand the conditions of each conjunction event. This can also be visualized with histograms or box plots.
#
# 5. **Dilution analysis**: We can analyze the 'DILUTION' column to understand the precision of each conjunction event. This can also be visualized with a histogram or a box plot.
#
# Let's start by filtering the data for a specific satellite. For this example, let's choose a satellite with NORAD_CAT_ID as 12345. If you have a specific satellite or constellation in mind, please provide the NORAD_CAT_ID(s).<FUNCTION_CALL />
#
# The filtered data for the satellite with NORAD_CAT_ID as 12345 is as follows:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>NORAD_CAT_ID_1</th>
#       <th>OBJECT_NAME_1</th>
#       <th>DSE_1</th>
#       <th>NORAD_CAT_ID_2</th>
#       <th>OBJECT_NAME_2</th>
#       <th>DSE_2</th>
#       <th>TCA</th>
#       <th>TCA_RANGE</th>
#       <th>TCA_RELATIVE_SPEED</th>
#       <th>MAX_PROB</th>
#       <th>DILUTION</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
#
# It appears that there are no conjunction events involving this satellite in the data. This could be due to the satellite not being involved in any conjunction events during the time period covered by the data, or the satellite ID provided may not be correct.
#
# Please provide a different NORAD_CAT_ID if you want to analyze a specific satellite. Alternatively, we can proceed with a general analysis using the entire dataset.

# %%
# Convert the TCA column to datetime
\
data['TCA'] = pd.to_datetime(data['TCA'])

\
# Create a new column for the date
\
data['DATE'] = data['TCA'].dt.date

\
# Count the number of conjunction events per day
\
conjunctions_per_day = data['DATE'].value_counts().sort_index()

\
# Plot the number of conjunction events over time
\
plt.figure(figsize=(10, 6))
\
plt.plot(conjunctions_per_day.index, conjunctions_per_day.values, color='skyblue')
\
plt.title('Number of Conjunction Events Over Time')
\
plt.xlabel('Date')
\
plt.ylabel('Number of Conjunction Events')
\
plt.show()

# %%
# Plot the distribution of MAX_PROB values
\
plt.figure(figsize=(10, 6))
\
plt.hist(data['MAX_PROB'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of Maximum Probability of Conjunction Events')
\
plt.xlabel('Maximum Probability')
\
plt.ylabel('Frequency')
\
plt.show()

# %%
# Plot the distribution of TCA_RELATIVE_SPEED values
\
plt.figure(figsize=(10, 6))
\
plt.hist(data['TCA_RELATIVE_SPEED'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of Relative Speed at Time of Closest Approach')
\
plt.xlabel('Relative Speed')
\
plt.ylabel('Frequency')
\
plt.show()

\
# Plot the distribution of TCA_RANGE values
\
plt.figure(figsize=(10, 6))
\
plt.hist(data['TCA_RANGE'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of Range at Time of Closest Approach')
\
plt.xlabel('Range')
\
plt.ylabel('Frequency')
\
plt.show()

# %%
# Plot the distribution of DILUTION values
\
plt.figure(figsize=(10, 6))
\
plt.hist(data['DILUTION'], bins=50, color='skyblue', edgecolor='black')
\
plt.title('Distribution of Dilution of Precision')
\
plt.xlabel('Dilution of Precision')
\
plt.ylabel('Frequency')
\
plt.show()

# %% [markdown]
# Question 3

# %%
# Filter the data to include only the conjunctions involving the RSO with NORAD ID 12345
rso_conjunctions = conjunctions_df[(conjunctions_df['NORAD_CAT_ID_1'] == 12345) | (conjunctions_df['NORAD_CAT_ID_2'] == 12345)]

# Resample the filtered data to daily frequency and count the number of conjunctions for each day
rso_conjunctions_by_day = rso_conjunctions.resample('D', on='TCA').size()

# Create a time series plot of the number of conjunctions over time
plt.figure(figsize=(10, 6))
plt.plot(rso_conjunctions_by_day.index, rso_conjunctions_by_day.values)
plt.xlabel('Date')
plt.ylabel('Number of Conjunctions')
plt.title('Number of Predicted Conjunctions Over Time for RSO with NORAD ID 12345')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-6e2fbd9c0841> in <cell line: 2>()
#       1 # Filter the data to include only the conjunctions involving the RSO with NORAD ID 12345
# ----> 2 rso_conjunctions = conjunctions_df[(conjunctions_df['NORAD_CAT_ID_1'] == 12345) | (conjunctions_df['NORAD_CAT_ID_2'] == 12345)]
#       3
#       4 # Resample the filtered data to daily frequency and count the number of conjunctions for each day
#       5 rso_conjunctions_by_day = rso_conjunctions.resample('D', on='TCA').size()
#
# NameError: name 'conjunctions_df' is not defined

# %%
# Convert the 'TCA' column to datetime format
conjunctions_df['TCA'] = pd.to_datetime(conjunctions_df['TCA'])

# Filter the data to include only the conjunctions involving the RSO with NORAD ID 12345
rso_conjunctions = conjunctions_df[(conjunctions_df['NORAD_CAT_ID_1'] == 12345) | (conjunctions_df['NORAD_CAT_ID_2'] == 12345)]

# Resample the filtered data to daily frequency and count the number of conjunctions for each day
rso_conjunctions_by_day = rso_conjunctions.resample('D', on='TCA').size()

# Create a time series plot of the number of conjunctions over time
plt.figure(figsize=(10, 6))
plt.plot(rso_conjunctions_by_day.index, rso_conjunctions_by_day.values)
plt.xlabel('Date')
plt.ylabel('Number of Conjunctions')
plt.title('Number of Predicted Conjunctions Over Time for RSO with NORAD ID 12345')
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9025dd08c084> in <cell line: 2>()
#       1 # Convert the 'TCA' column to datetime format
# ----> 2 conjunctions_df['TCA'] = pd.to_datetime(conjunctions_df['TCA'])
#       3
#       4 # Filter the data to include only the conjunctions involving the RSO with NORAD ID 12345
#       5 rso_conjunctions = conjunctions_df[(conjunctions_df['NORAD_CAT_ID_1'] == 12345) | (conjunctions_df['NORAD_CAT_ID_2'] == 12345)]
#
# NameError: name 'conjunctions_df' is not defined
